# %%
import numpy as np
import pandas as pd

# %%
ser1=pd.Series(np.random.randint(100,size=(9)),index=['a','a','a','b','b','c','c','d','d'])
ser1
# Out:
# a    26
# a    88
# a    46
# b    61
# b    11
# c    17
# c    20
# d    35
# d    34
# dtype: int64

# %%
ser1.index
# Out:
# Index(['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], dtype='object')

# %%
ser1.index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,2,1,2,1,2]]
ser1
# Out:
# a  1    26
#    2    88
#    3    46
# b  1    61
#    2    11
# c  1    17
#    2    20
# d  1    35
#    2    34
# dtype: int64

# %%
ser1.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2),
#             ('d', 1),
#             ('d', 2)],
#            )

# %%
df = ser1.unstack()

# %%
df
# Out:
#       1     2     3
# a  26.0  88.0  46.0
# b  61.0  11.0   NaN
# c  17.0  20.0   NaN
# d  35.0  34.0   NaN

# %%
df.stack()
# Out:
# a  1    26.0
#    2    88.0
#    3    46.0
# b  1    61.0
#    2    11.0
# c  1    17.0
#    2    20.0
# d  1    35.0
#    2    34.0
# dtype: float64

# %%
ser1['a']
# Out:
# 1    26
# 2    88
# 3    46
# dtype: int64

# %%
ser1[['a','c']]
# Out:
# a  1    26
#    2    88
#    3    46
# c  1    17
#    2    20
# dtype: int64

# %%
ser1['a'][2]
# Out:
# 88

# %%
ser1.loc[['a','d'],[1,3]]
# Out:
# a  1    26
#    3    46
# d  1    35
# dtype: int64

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (60/60), 20.24 MiB | 3.96 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")

# %%
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.columns=['City','Region','Country','AirQuality','WaterPollution']

# %%
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
df['Region'] = df['Region'].map(lambda x:x.replace('"',''))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x:x.replace('"',''))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df.loc[1,"Country"]
# Out:
# ' United States of America'

# %%
df['Country'] = df['Country'].map(lambda x:x.strip())
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df[df['Country']=='France']
# Out:
#                      City          Region Country  AirQuality  WaterPollution
# 13                  Paris   Ile-de-France  France   34.024390       43.121693
# 24                  Tours                  France   84.375000        6.250000
# 38           Villeurbanne                  France   75.000000       50.000000
# 48                 Rennes                  France   62.500000       35.000000
# 49                  Lille                  France   48.913043       35.526316
# 90               Grenoble                  France   34.090909       26.470588
# 109               Le Mans                  France   95.000000       50.000000
# 111              Bordeaux                  France   68.478261       42.647059
# 466               Avignon                  France   57.142857       66.666667
# 467           Montpellier                  France   71.666667       29.545455
# 472               Orleans                  France   83.333333       50.000000
# ...

# %%
df.head()
# Out:
#                City                 Region                   Country  \
# 0     New York City               New York  United States of America
# 1  Washington, D.C.   District of Columbia  United States of America
# 2     San Francisco             California  United States of America
# 3            Berlin                                          Germany
# 4       Los Angeles             California  United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df=pd.pivot_table(df,index=['Country','City'])
# Out:
# <ipython-input-84-1fbdb84e8141>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df=pd.pivot_table(df,index=['Country','City'])

# %%
df
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df['AirPollution']=100-df['AirQuality']

# %%
df['WaterQuality']=100-df['WaterPollution']

# %%
df
# Out:
#                       AirQuality  WaterPollution  AirPollution  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000     50.000000     50.000000
#             Farah     100.000000        0.000000      0.000000    100.000000
#             Herat      43.750000       31.250000     56.250000     68.750000
#             Kabul      18.421053       81.060606     81.578947     18.939394
#             Kandahar    0.000000       75.000000    100.000000     25.000000
# ...                          ...             ...           ...           ...
# Zambia      Mansa      75.000000       25.000000     25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000     50.000000     25.000000
#             Bulawayo   67.857143       71.428571     32.142857     28.571429
#             Harare     38.461538       87.500000     61.538462     12.500000
#             Masvingo   25.000000       62.500000     75.000000     37.500000
#
# [3895 rows x 4 columns]

# %%
df = df[['AirQuality','AirPollution','WaterQuality','WaterPollution']]
df
# Out:
#                       AirQuality  AirPollution  WaterQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000     50.000000     50.000000       50.000000
#             Farah     100.000000      0.000000    100.000000        0.000000
#             Herat      43.750000     56.250000     68.750000       31.250000
#             Kabul      18.421053     81.578947     18.939394       81.060606
#             Kandahar    0.000000    100.000000     25.000000       75.000000
# ...                          ...           ...           ...             ...
# Zambia      Mansa      75.000000     25.000000     75.000000       25.000000
# Zimbabwe    Bindura    50.000000     50.000000     25.000000       75.000000
#             Bulawayo   67.857143     32.142857     28.571429       71.428571
#             Harare     38.461538     61.538462     12.500000       87.500000
#             Masvingo   25.000000     75.000000     37.500000       62.500000
#
# [3895 rows x 4 columns]

# %%
df.columns=[['Air','Air','Water','Water'],['AirQuality','AirPollution','WaterQuality','WaterPollution']]

# %%
df.columns.names=['Object','Info']
df
# Out:
# Object                       Air                     Water
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000   100.000000       0.000000
#             Herat      43.750000    56.250000    68.750000      31.250000
#             Kabul      18.421053    81.578947    18.939394      81.060606
#             Kandahar    0.000000   100.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    75.000000      25.000000
# Zimbabwe    Bindura    50.000000    50.000000    25.000000      75.000000
#             Bulawayo   67.857143    32.142857    28.571429      71.428571
#             Harare     38.461538    61.538462    12.500000      87.500000
#             Masvingo   25.000000    75.000000    37.500000      62.500000
#
# ...

# %%
df.loc[['Argentina'],['Water']]
# Out:
# Object                                   Water
# Info                              WaterQuality WaterPollution
# Country   City
# Argentina Avellaneda                  0.000000     100.000000
#           Bahia Blanca               41.666667      58.333333
#           Bariloche                  58.333333      41.666667
#           Buenos Aires               45.156250      54.843750
#           Comodoro Rivadavia         41.666667      58.333333
#           Cordoba                    41.666667      58.333333
#           La Plata                   36.363636      63.636364
#           La Rioja                   50.000000      50.000000
#           Lomas de Zamora            62.500000      37.500000
#           Mar del Plata              64.285714      35.714286
#           Mendoza                    46.428571      53.571429
#           Pilar                       0.000000     100.000000
#           Quilmes                    75.000000      25.000000
# ...

# %%
df
# Out:
# Object                       Air                     Water
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df.swaplevel('Country','City')
# Out:
# Object                       Air                     Water
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# City     Country
# Andkhoy  Afghanistan   50.000000    50.000000    50.000000      50.000000
# Farah    Afghanistan  100.000000     0.000000   100.000000       0.000000
# Herat    Afghanistan   43.750000    56.250000    68.750000      31.250000
# Kabul    Afghanistan   18.421053    81.578947    18.939394      81.060606
# Kandahar Afghanistan    0.000000   100.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Mansa    Zambia        75.000000    25.000000    75.000000      25.000000
# Bindura  Zimbabwe      50.000000    50.000000    25.000000      75.000000
# Bulawayo Zimbabwe      67.857143    32.142857    28.571429      71.428571
# Harare   Zimbabwe      38.461538    61.538462    12.500000      87.500000
# Masvingo Zimbabwe      25.000000    75.000000    37.500000      62.500000
#
# ...

# %%
df.sort_index(ascending=False)
# Out:
# Object                       Air                     Water
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Zimbabwe    Masvingo   25.000000    75.000000    37.500000      62.500000
#             Harare     38.461538    61.538462    12.500000      87.500000
#             Bulawayo   67.857143    32.142857    28.571429      71.428571
#             Bindura    50.000000    50.000000    25.000000      75.000000
# Zambia      Mansa      75.000000    25.000000    75.000000      25.000000
# ...                          ...          ...          ...            ...
# Afghanistan Kandahar    0.000000   100.000000    25.000000      75.000000
#             Kabul      18.421053    81.578947    18.939394      81.060606
#             Herat      43.750000    56.250000    68.750000      31.250000
#             Farah     100.000000     0.000000   100.000000       0.000000
#             Andkhoy    50.000000    50.000000    50.000000      50.000000
#
# ...

# %%
df
# Out:
# Object                       Air                     Water
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000   100.000000       0.000000
#             Herat      43.750000    56.250000    68.750000      31.250000
#             Kabul      18.421053    81.578947    18.939394      81.060606
#             Kandahar    0.000000   100.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    75.000000      25.000000
# Zimbabwe    Bindura    50.000000    50.000000    25.000000      75.000000
#             Bulawayo   67.857143    32.142857    28.571429      71.428571
#             Harare     38.461538    61.538462    12.500000      87.500000
#             Masvingo   25.000000    75.000000    37.500000      62.500000
#
# ...
