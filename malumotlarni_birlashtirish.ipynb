# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# Cloning into 'Practicum_Datasets'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 17), reused 16 (delta 1), pack-reused 0
# Receiving objects: 100% (60/60), 20.24 MiB | 11.89 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
movies=pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_movies.csv")
# Out:
# <ipython-input-4-36ef31d173dd>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies=pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_movies.csv")

# %%
ratings= pd.read_csv('/content/Practicum_Datasets/IMDb/IMDb_ratings.csv')

# %%
movies.sample(3)
# Out:
#       imdb_title_id                          title  \
# 25070     tt0098987  Le avventure di Ford Fairlane
# 66386     tt2331053              Santa's Boot Camp
# 45237     tt0402115      Just Sex and Nothing Else
#
#                         original_title  year date_published  \
# 25070  The Adventures of Ford Fairlane  1990     1990-07-11
# 66386                Santa's Boot Camp  2016     2016-11-07
# 45237           Csak szex és más semmi  2005     2005-12-08
#
#                            genre  duration  country   language  \
# 25070  Action, Adventure, Comedy       104      USA    English
# 66386  Adventure, Comedy, Family        93      USA    English
# 45237                     Comedy        97  Hungary  Hungarian
#
#              director                        writer  \
# 25070    Renny Harlin    Daniel Waters, James Cappe
# 66386    Ken Feinberg   Kelly Nettles, Ken Feinberg
# 45237  Krisztina Goda  Réka Divinyi, Krisztina Goda
#
#                 production_company  \
# ...

# %%
ratings.sample(4)
# Out:
#       imdb_title_id  weighted_average_vote  total_votes
# 73698     tt4088588                    7.9         3510
# 56804     tt1311083                    4.7          110
# 23577     tt0094078                    5.4          815
# 51441     tt0914797                    6.8        14859

# %%
movies_ratings = pd.merge(movies,ratings)

# %%
movies_ratings.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
movies_ratings.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'budget',
#        'weighted_average_vote', 'total_votes'],
#       dtype='object')

# %%
df=movies_ratings[['original_title','year','director',
       'weighted_average_vote']]

# %%
df.sample(3)
# Out:
#           original_title  year               director  weighted_average_vote
# 19787  Die bleierne Zeit  1981  Margarethe von Trotta                    7.5
# 85321           Uncorked  2020         Prentice Penny                    6.2
# 63794  The Frozen Ground  2013           Scott Walker                    6.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85855 entries, 0 to 85854
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   original_title         85855 non-null  object
#  1   year                   85855 non-null  object
#  2   director               85768 non-null  object
#  3   weighted_average_vote  85855 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 3.3+ MB

# %%
df[df['year']=='TV Movie 2019']
# Out:
#       original_title           year     director  weighted_average_vote
# 83917  Bad Education  TV Movie 2019  Cory Finley                    7.1

# %%
df.loc[83917,'year']='2019'

# %%
df['year'] = df['year'].astype('int64')
# Out:
# <ipython-input-56-08e81c6efb09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype('int64')

# %%
df=df.rename(columns={'weighted_average_vote':'rating'})

# %%
df[df['director']=='Quentin Tarantino'].sort_values('rating', ascending=False)
# Out:
#                            original_title  year           director  rating
# 28381                        Pulp Fiction  1994  Quentin Tarantino     8.9
# 79374  Kill Bill: The Whole Bloody Affair  2011  Quentin Tarantino     8.8
# 62660                    Django Unchained  2012  Quentin Tarantino     8.4
# 26859                      Reservoir Dogs  1992  Quentin Tarantino     8.3
# 43404                Inglourious Basterds  2009  Quentin Tarantino     8.3
# 39151                   Kill Bill: Vol. 1  2003  Quentin Tarantino     8.1
# 44214                   Kill Bill: Vol. 2  2004  Quentin Tarantino     8.0
# 71309                   The Hateful Eight  2015  Quentin Tarantino     7.8
# 81897    Once Upon a Time... in Hollywood  2019  Quentin Tarantino     7.6
# 30706                        Jackie Brown  1997  Quentin Tarantino     7.5
# 52677                         Death Proof  2007  Quentin Tarantino     7.0
# ...
