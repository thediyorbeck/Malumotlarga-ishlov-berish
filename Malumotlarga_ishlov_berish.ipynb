# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("sample_data/california_housing_test.csv",nrows=10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv')

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
# ...

# %%
df.to_excel('avtomobil_data.xlsx',index=False, columns=['company','body-style','horsepower','price'])

# %%
df.to_csv('avto.csv',index=False)

# %%
df2=pd.read_csv('avto.csv',nrows=10)

# %%
df2
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3         audi        sedan        99.8   176.6         ohc             four
# 4         audi        sedan        99.4   176.6         ohc             five
# 5         audi        sedan        99.8   177.3         ohc             five
# 6         audi        wagon       105.8   192.7         ohc             five
# 7          bmw        sedan       101.2   176.8         ohc             four
# 8          bmw        sedan       101.2   176.8         ohc             four
# 9          bmw        sedan       101.2   176.8         ohc              six
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0
# 1         111               21  16500.0
# ...

# %%
df2.to_hdf('data.h5',key='avto')

# %%
from pandas.io.pytables import HDFStore
hdfobj=HDFStore('data.h5')

# %%
hdfobj.keys()
# Out:
# ['/avto']

# %%
hdfobj['avto']
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3         audi        sedan        99.8   176.6         ohc             four
# 4         audi        sedan        99.4   176.6         ohc             five
# 5         audi        sedan        99.8   177.3         ohc             five
# 6         audi        wagon       105.8   192.7         ohc             five
# 7          bmw        sedan       101.2   176.8         ohc             four
# 8          bmw        sedan       101.2   176.8         ohc             four
# 9          bmw        sedan       101.2   176.8         ohc              six
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0
# 1         111               21  16500.0
# ...

# %%
df3=pd.read_csv("sample_data/california_housing_test.csv",nrows=10)
df3
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
hdfobj.put('cahouses',df3)

# %%
hdfobj.keys()
# Out:
# ['/avto', '/cahouses']

# %%
hdfobj['cahouses']
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
hdfobj.close()

# %%
pd.read_hdf('data.h5',key='cahouses')
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
data=pd.read_html("https://en.wikipedia.org/wiki/Tashkent")
len(data)
# Out:
# 18

# %%
data[10]
# Out:
#     Nr       District  Population (2021)[4]  Area (km2)[66][65]  \
# 0    1       Bektemir                 31400               17.83
# 1    2      Chilanzar                260700               29.94
# 2    3      Yashnobod                258800               33.70
# 3    4        Mirobod                142800               17.10
# 4    5  Mirzo Ulugbek                285000               35.15
# 5    6        Sergeli                105700               37.36
# 6    7   Shayxontoxur                348300               29.70
# 7    8        Olmazor                377100               34.50
# 8    9        Uchtepa                278200               24.00
# 9   10     Yakkasaray                121600               14.60
# 10  11      Yunusabad                352000               40.60
# 11  12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# 0                 1761  NaN
# 1                 8707  NaN
# 2                 7680  NaN
# ...

# %%
df=pd.DataFrame(data[10])
df.index=df['Nr']

# %%
df
# Out:
#     Nr       District  Population (2021)[4]  Area (km2)[66][65]  \
# Nr
# 1    1       Bektemir                 31400               17.83
# 2    2      Chilanzar                260700               29.94
# 3    3      Yashnobod                258800               33.70
# 4    4        Mirobod                142800               17.10
# 5    5  Mirzo Ulugbek                285000               35.15
# 6    6        Sergeli                105700               37.36
# 7    7   Shayxontoxur                348300               29.70
# 8    8        Olmazor                377100               34.50
# 9    9        Uchtepa                278200               24.00
# 10  10     Yakkasaray                121600               14.60
# 11  11      Yunusabad                352000               40.60
# 12  12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# Nr
# 1                 1761  NaN
# 2                 8707  NaN
# 3                 7680  NaN
# ...

# %%
df.drop('Nr',axis=1,inplace=True)

# %%
df
# Out:
#          District  Population (2021)[4]  Area (km2)[66][65]  \
# Nr
# 1        Bektemir                 31400               17.83
# 2       Chilanzar                260700               29.94
# 3       Yashnobod                258800               33.70
# 4         Mirobod                142800               17.10
# 5   Mirzo Ulugbek                285000               35.15
# 6         Sergeli                105700               37.36
# 7    Shayxontoxur                348300               29.70
# 8         Olmazor                377100               34.50
# 9         Uchtepa                278200               24.00
# 10     Yakkasaray                121600               14.60
# 11      Yunusabad                352000               40.60
# 12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# Nr
# 1                 1761  NaN
# 2                 8707  NaN
# 3                 7680  NaN
# 4                 8351  NaN
# ...
